# %%
! pip3 install pandas
import pandas


print(pandas.__version__)
# Out:
# ...
#
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# 2.3.3

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"names":["harrry","rohan"],'marks':[23,44]})
print(df)
print(type(df))
# Out:
#     names  marks
# 0  harrry     23
# 1   rohan     44
# <class 'pandas.core.frame.DataFrame'>

# %%
s1=pd.Series([1,2,3,4],index=[0,1,2,3])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data={
    'name':['eshanth','arjun','pab'],
    'city':['pune','mumbai','delhi'],
    'age':[12,18,17],
    'salary':[223333,44343,54343434]
}

df=pd.DataFrame(data)
print(df)
# Out:
#       name    city  age    salary
# 0  eshanth    pune   12    223333
# 1    arjun  mumbai   18     44343
# 2      pab   delhi   17  54343434

# %%
datalist=[
    ['eshant',18,'pune',1000],
    ['arjun',17,'delhi',100],
    ['pab',10,'mumbai',8000],
    ['arr',11,'hyd',1000],
]
df=pd.DataFrame(datalist)
print(df)
col=["name",'age','city','salary']
df=pd.DataFrame(datalist,columns=col)
print(df)
# Out:
#         0   1       2     3
# 0  eshant  18    pune  1000
# 1   arjun  17   delhi   100
# 2     pab  10  mumbai  8000
# 3     arr  11     hyd  1000
#      name  age    city  salary
# 0  eshant   18    pune    1000
# 1   arjun   17   delhi     100
# 2     pab   10  mumbai    8000
# 3     arr   11     hyd    1000

# %%
print(df['name'])
print(df['city'])
print(df[['name','city']])
df['designation']=['mr','res','doc','top']
print(df)
# Out:
# 0    eshant
# 1     arjun
# 2       pab
# 3       arr
# Name: name, dtype: object
# 0      pune
# 1     delhi
# 2    mumbai
# 3       hyd
# Name: city, dtype: object
#      name    city
# 0  eshant    pune
# 1   arjun   delhi
# 2     pab  mumbai
# 3     arr     hyd
#      name  age    city  salary designation
# 0  eshant   18    pune    1000          mr
# 1   arjun   17   delhi     100         res
# 2     pab   10  mumbai    8000         doc
# 3     arr   11     hyd    1000         top

# %%
print(df.drop('designation',axis=1,inplace=True))
print(df)
# Out:
# None
#      name  age    city  salary
# 0  eshant   18    pune    1000
# 1   arjun   17   delhi     100
# 2     pab   10  mumbai    8000
# 3     arr   11     hyd    1000

# %%
print(df.drop(['city','salary'],axis=1))
print(df.drop(0,axis=0))
# Out:
#      name  age
# 0  eshant   18
# 1   arjun   17
# 2     pab   10
# 3     arr   11
#     name  age    city  salary
# 1  arjun   17   delhi     100
# 2    pab   10  mumbai    8000
# 3    arr   11     hyd    1000

# %%
print(df.loc[[0,1]][['city','salary']])
# Out:
#     city  salary
# 0   pune    1000
# 1  delhi     100

# %%
df[(df['age']>11) & (df['city']=='pune')]
# Out:
#      name  age  city  salary
# 0  eshant   18  pune    1000
