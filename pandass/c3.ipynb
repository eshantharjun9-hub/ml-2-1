# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../data/tipss.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(df['day'])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill','day','tip']].head()
# Out:
#    total_bill  day   tip
# 0       16.99  Sun  1.01
# 1       10.34  Sun  1.66
# 2       21.01  Sun  3.50
# 3       23.68  Sun  3.31
# 4       24.59  Sun  3.61

# %%
df['country']='india'
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size country
# 0       16.99  1.01  Female     No  Sun  Dinner     2   india
# 1       10.34  1.66    Male     No  Sun  Dinner     3   india
# 2       21.01  3.50    Male     No  Sun  Dinner     3   india
# 3       23.68  3.31    Male     No  Sun  Dinner     2   india
# 4       24.59  3.61  Female     No  Sun  Dinner     4   india

# %%
df['biil_per_person']=round(df['total_bill']/df['size'],2)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size country  biil_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2   india             8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3   india             3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3   india             7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2   india            11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4   india             6.15

# %%
df['total_paid']=df['tip']+df['total_bill']
df.head()
df.shape
# Out:
# (244, 10)

# %%
df.iloc[6:10:2]
df.iloc[[0,1,2,3]]
df.iloc[10:21,2:6:2]
df.iloc[6]
df.iloc[-1]
df.iloc[1:6]
# Out:
#    total_bill   tip     sex smoker  day    time  size country  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3   india
# 2       21.01  3.50    Male     No  Sun  Dinner     3   india
# 3       23.68  3.31    Male     No  Sun  Dinner     2   india
# 4       24.59  3.61  Female     No  Sun  Dinner     4   india
# 5       25.29  4.71    Male     No  Sun  Dinner     4   india
#
#    biil_per_person  total_paid
# 1             3.45       12.00
# 2             7.00       24.51
# 3            11.84       26.99
# 4             6.15       28.20
# 5             6.32       30.00

# %%
print(list(df.columns))
df.iloc[10:15,[4,0]]
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'country', 'biil_per_person', 'total_paid']
#     day  total_bill
# 10  Sun       10.27
# 11  Sun       35.26
# 12  Sun       15.42
# 13  Sun       18.43
# 14  Sun       14.83

# %%
df.iloc[(df['size']>4).values]
# Out:
#      total_bill   tip     sex smoker   day    time  size country  \
# 125       29.80  4.20  Female     No  Thur   Lunch     6   india
# 141       34.30  6.70    Male     No  Thur   Lunch     6   india
# 142       41.19  5.00    Male     No  Thur   Lunch     5   india
# 143       27.05  5.00  Female     No  Thur   Lunch     6   india
# 155       29.85  5.14  Female     No   Sun  Dinner     5   india
# 156       48.17  5.00    Male     No   Sun  Dinner     6   india
# 185       20.69  5.00    Male     No   Sun  Dinner     5   india
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5   india
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5   india
#
#      biil_per_person  total_paid
# 125             4.97       34.00
# 141             5.72       41.00
# 142             8.24       46.19
# 143             4.51       32.05
# 155             5.97       34.99
# 156             8.03       53.17
# 185             4.14       25.69
# 187             6.09       32.46
# ...

# %%
df.loc[5:10,['tip','size']]
# Out:
#      tip  size
# 5   4.71     4
# 6   2.00     2
# 7   3.12     4
# 8   1.96     2
# 9   3.23     2
# 10  1.71     2

# %%
df.loc[100,['day','tip']]
# Out:
# day    Fri
# tip    2.5
# Name: 100, dtype: object

# %%
df[(df['day']=="Sun") & (df['size']>3)].shape[0]
df[(df['day']=="Sun") | (df['time']=="Dinner")].shape[0]
# Out:
# 176

# %%
df[~(df['day']=="Sun")].shape[0]
# Out:
# 168

# %%
df[df['tip']>4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df[df['tip'>6]]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df[df['time']=="Dinner"]['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Fri     12
# Thur     1
# Name: count, dtype: int64

# %%
df['bill_type']='normal'
df.loc[df['total_bill']>40,'bill_type']="Big"
df['bill_type'].value_counts()
# Out:
# bill_type
# normal    234
# Big        10
# Name: count, dtype: int64

# %%
t=pd.read_csv('/Users/eshantharjun/Desktop/ml/data/titanicdataset.csv')
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(t[t["Age"]>40].shape[0])
print(t[t["Age"]<=40].shape[0])
# Out:
# 150
# 564

# %%
t[(t["Age"]>40) & (t["Survived"]==1) & (t['Sex']=="male")].shape[0]
t[(t["Age"]<30) & (t["Survived"]==1) & (t["Sex"]=="female") & (t["Pclass"]==2)].shape[0]
# Out:
# 38

# %%
t[t['Pclass']==1].shape[0]
# Out:
# 216

# %%
t[(t['SibSp'] == 0) & (t['Parch'] == 0) & (t['Sex']=="male")].shape[0]
# Out:
# 411

# %%
(t['Age']<10) & (t['Pclass']==1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool
