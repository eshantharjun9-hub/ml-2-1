# %% [markdown]
# # 📊 Plotting for Machine Learning
#
# 📂 `Titanic-Dataset.csv` and `mpg.csv` — keep both in this folder.
#
# Every plot today answers **one question**, and the answer changes what you do next.
#
# **How many columns am I looking at?**
#
# | columns | called | today |
# |---|---|---|
# | 1 | univariate | `histplot` · `countplot` |
# | 2 | bivariate | `boxplot` · `scatterplot` · `hue=` |
# | 3+ | multivariate | `pairplot` · `heatmap` |

# %%
! pip3 install matplotlib
! pip3 install seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eshantharjun/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/eshantharjun/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# ^C
# Requirement already satisfied: seaborn in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eshantharjun/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/eshantharjun/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in /Users/eshantharjun/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/eshantharjun/Desktop/ml/data/titanicdataset.csv')   # demo
mpg = pd.read_csv('/Users/eshantharjun/Desktop/ml/data/mpg.csv')               # your practice

print(df.shape, mpg.shape)

df.head(1)
# Out:
# (891, 12) (398, 9)
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# ---
# ## Why plot at all
#
# On Day 5 you found `Fare` has mean **32.20** and median **14.45**, and you filled with the
# median because the mean looked wrong.
#
# Today you will see *why* in one picture.

# %% [markdown]
# ---
# ## 0️⃣ The matplotlib skeleton
#
# Three lines around every plot:
#
# ```python
# plt.figure(figsize=(7, 4))   # size
# sns.something(...)           # the plot
# plt.title('...')             # label it
# plt.show()
# ```

# %%
# a plain histogram of Fare, with a size and a title -> histplot 
plt.figure(figsize=(7,4))
sns.histplot(data=df,x='Fare',color="red")
plt.title("fare")
plt.grid()
plt.show()

# %%
# save that same chart as a file

# %% [markdown]
# `plt.savefig('name.png')` must come **before** `plt.show()` — after it, the figure is gone.

# %% [markdown]
# ---
# # 1️⃣ Univariate — one column at a time
#
# **The question:** can I use this feature at all?

# %% [markdown]
# ### `histplot` — how is one number spread out?

# %%
# distribution of Fare
plt.figure(figsize=(7,4))
sns.histplot(data=df,x="Fare")
plt.title("Fare")
plt.grid()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.grid()
#
# NameError: name 'plt' is not defined

# %%
# distribution of Age
plt.figure(figsize=(7,2))
sns.histplot(data=df,x="Age")
plt.title("Age")
plt.show()

# %% [markdown]
# | | mean | median | max |
# |---|---|---|---|
# | Fare | 32.20 | **14.45** | 512 |
# | Age | 29.70 | 28.00 | 80 |
#
# `Fare` has a long tail to the right — a few people paid enormous amounts and dragged the
# mean above the median. `Age` is roughly symmetric.
#
# ⭐ **The shape decides your fill.** Long tail → median. Symmetric → either works.

# %% [markdown]
# ### `countplot` — how many in each category?

# %%
# how many survived and how many died
plt.Figure(figsize=(7,2))
sns.countplot(data=df,x="Survived")
plt.show()

# %% [markdown]
# **549 died, 342 survived** — that is **61.6%**.
#
# ⭐ A model that always predicts "died" scores 61.6% without learning anything.
# Any accuracy below that is worse than saying nothing.

# %% [markdown]
# ### 🧩 Try these — on `mpg.csv`

# %% [markdown]
# **Q1** Plot the distribution of `mpg`. Is it skewed? If this column had blanks, would you
# fill with the mean or the median?

# %%
# Q1
plt.Figure(figsize=(7,2))
sns.histplot(data=mpg,x="mpg",bins=25)
plt.title("Mpg")
plt.show()

# %% [markdown]
# **Q2** How many cars come from each `origin`? What would that imbalance do to a model
# trained on this data?

# %%
# Q2
plt.Figure(figsize=(7,2))
sns.countplot(data=mpg,x="origin")
plt.title("Mpg")
plt.show()

# %% [markdown]
# ---
# # 2️⃣ Bivariate — two columns together
#
# **The question:** does this feature separate the thing I am predicting?

# %% [markdown]
# ### `boxplot` — does a number differ across groups?

# %%
# Fare on its own — read the box, the whiskers, the dots
plt.Figure(figsize=(7,2))
sns.boxplot(data=df,x="Survived",y="Fare")
plt.title("Fare")
plt.show()

# %% [markdown]
# The box is the middle half of the data. The line inside is the median. The dots beyond the
# whiskers are outliers — `Fare` has **116** of them.

# %%
# Fare split by Survived
plt.Figure(figsize=(7,2))
sns.boxplot(data=df,x="Survived",y="Fare")
plt.title("Fare")
plt.show()

# %%
# Age split by Survived
plt.Figure(figsize=(7,2))
sns.boxplot(data=df,x="Survived",y="Age")
plt.title("Fare")
plt.show()

# %% [markdown]
# | | died | survived |
# |---|---|---|
# | median `Fare` | 10.50 | **26.00** |
# | median `Age` | 28.0 | 28.0 |
#
# ⭐ `Fare` separates the two groups. `Age` does not. **A feature that does not separate
# your classes will not help your model.**

# %% [markdown]
# ### `scatterplot` — do two numbers move together?

# %%
# Age against Fare
plt.Figure(figsize=(7,2))
sns.scatterplot(data=df,x="Age",y="Fare",hue="Sex")
plt.title("Age vs Fare")
plt.show()

# %% [markdown]
# A shapeless cloud. These two columns barely relate — the correlation is only 0.096.

# %% [markdown]
# ### `hue=` — the argument that turns any plot into an ML plot
#
# Add one word and the target appears inside the picture.

# %%
# the same scatter, coloured by Survived

# %%
# and a countplot of Pclass, coloured by Survived

# %% [markdown]
# The scatter now shows where survivors sit. The countplot shows both the survival split
# **and** the group sizes at once — 216, 184, **491**.
#
# ⭐ That is the "read the group size next to the group average" rule from last week,
# drawn instead of calculated.

# %% [markdown]
# ### 🧩 Try these — on `mpg.csv`

# %% [markdown]
# **Q3** Boxplot `mpg` split by `origin`, then split by `cylinders` instead.
# Which of the two separates the groups more clearly?

# %%
# Q3

# %% [markdown]
# **Q4** Scatter `weight` against `mpg`, coloured by `origin`.
# Describe the relationship in one line, and say what the colours add.

# %%
# Q4
plt.Figure(figsize=(7,2))
sns.scatterplot(data=mpg,x="mpg",y='weight',hue='origin')
plt.show()

# %% [markdown]
# ---
# # 3️⃣ Multivariate — everything at once
#
# **The question:** which features matter, and which ones repeat each other?

# %% [markdown]
# ### `pairplot` — every pair of columns in one grid

# %%
# pairplot of Age, Fare, Pclass and Survived, coloured by Survived

# %%
# pairplot of total_bil,age and size diag_kind is hist colored by sex

# %% [markdown]
# Scatter plots off the diagonal, distributions along it. Univariate and bivariate in a
# single line.
#
# ⚠️ `pairplot` builds its own figure, so `plt.figure(figsize=...)` has no effect on it.
# Use `height=` instead. It is also slow on wide tables — pick your columns first.

# %% [markdown]
# ### `heatmap` — the same idea as numbers

# %%
# correlation of the numeric columns

# %%
# the same thing as a heatmap, with the numbers written on it

# %% [markdown]
# Correlation with `Survived`:
#
# | feature | correlation |
# |---|---|
# | `Pclass` | **−0.34** |
# | `Fare` | 0.26 |
# | `Parch` | 0.08 |
# | `Age` | −0.08 |
#
# ⭐ A heatmap does two jobs: it shows **what predicts your target**, and it shows
# **which features are duplicates of each other**.

# %% [markdown]
# ### 🧩 Try this — on `mpg.csv`

# %% [markdown]
# **Q5** ⭐ Heatmap of the numeric columns in `mpg`. Two parts:
#
# 1. Which feature predicts `mpg` best?
# 2. Find two features that are almost the same thing — if you had to drop one, which
#    and why?

# %%
# Q5

# %% [markdown]
# ---
# ## 📌 Which plot, when
#
# | Your question | Columns | Plot |
# |---|---|---|
# | How is one number spread out? | 1 numeric | `histplot` |
# | How many in each category? | 1 categorical | `countplot` |
# | Does this number differ across groups? | numeric + categorical | `boxplot` |
# | Do two numbers move together? | 2 numeric | `scatterplot` |
# | *…and does the target split them?* | **+ target** | **add `hue=`** |
# | Quick look at everything | many numeric | `pairplot` |
# | Which features matter, which repeat? | many numeric | `heatmap` |
#
# ### The skeleton
# ```python
# plt.figure(figsize=(7, 4))
# sns.histplot(data=df, x='column')
# plt.title('...')
# plt.show()
# ```
#
# ### What each plot decided today
# - `Fare` is skewed → **fill with the median**
# - 61.6% died → **any model must beat 61.6%**
# - `Fare` separates survivors, `Age` does not → **keep Fare, question Age**
# - `Pclass` correlates −0.34 with survival → **the strongest single number you have**
