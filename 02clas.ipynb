# %%
x="hello world"

# %%
print(x.upper())
print(x)
print(x.capitalize())
print(x.title())
# Out:
# HELLO WORLD
# hello world
# Hello world
# Hello World

# %%
x = "# hh *   he*ll  #** *"
print(x.strip("#*"))
# Out:
#  hh *   he*ll  #**

# %%
x="  hello  "
print(x.lstrip())
print(x.rstrip())
# Out:
# hello
#   hello

# %%
x="eshanth arjun"
print(x.replace("arjun","pabbati"))
print(x)
# Out:
# eshanth pabbati
# eshanth arjun

# %%
x="vedam,sch.ool.of,tech"
x=x.replace(",","*")
x=x.replace(".",",")
x=x.replace("*",".")


print(x)
# Out:
# vedam.sch,ool,of.tech

# %%
x="welcome to pune"
lis=x.split()
print(lis)
# Out:
# ['welcome', 'to', 'pune']

# %%
x="charle-bravo-alpha"
x=x.replace("-"," ")
x=x.upper()
li=x.split()
li.reverse()
print(li)
print(" ".join(li))
# Out:
# ['ALPHA', 'BRAVO', 'CHARLE']
# ALPHA BRAVO CHARLE
