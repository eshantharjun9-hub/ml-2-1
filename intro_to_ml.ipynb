# %%
# !pip3 install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sklearn
import pandas as pd

# %%
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
df=pd.read_csv('/Users/eshantharjun/Desktop/ml/data/titanicdataset.csv')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# age medaina
# embarked  2 drop
# cabin name ticket passid
df = df.drop(['Cabin', 'Ticket', 'Name', 'PassengerId'], axis=1)
df['Age'] = df['Age'].fillna(df['Age'].median())
df.dropna(subset='Embarked',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.5+ KB

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
print(x.head())
y.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test.count()
# Out:
# Pclass      178
# Sex         178
# Age         178
# SibSp       178
# Parch       178
# Fare        178
# Embarked    178
# dtype: int64

# %%
x_train.head()
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 708       1  female  22.0      0      0  151.5500        S
# 240       3  female  28.0      1      0   14.4542        C
# 382       3    male  32.0      0      0    7.9250        S
# 792       3  female  28.0      8      2   69.5500        S
# 683       3    male  14.0      5      2   46.9000        S

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fc/d5d3pfb109dbns6hx1zv7d700000gn/T/ipykernel_80411/3744772988.py in ?()
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 model=KNeighborsClassifier()
# ----> 3 model.fit(x_train,y_train)
#
# ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/sklearn/neighbors/_classification.py in ?(self, X, y)
#     235         -------
#     236         self : KNeighborsClassifier
# ...

# %%
cat_cols=['Sex',"Embarked"]

# %%
ct=ColumnTransformer([('cat',OneHotEncoder(sparse_output=False),cat_cols)],remainder='passthrough')
x_train_final = ct.fit_transform(x_train)
x_test_final=ct.fit_transform(x_test)

# %%
x_train.shape
x_train_final.shape
# Out:
# (711, 10)
