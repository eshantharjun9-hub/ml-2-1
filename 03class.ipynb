# %%
name="eshanth"
age=18
print("Name of the student is",name,"and age is",age)
print(f"Name of the studen is {name} and age is {age}")
# Out:
# Name of the student is eshanth and age is 18
# Name of the studen is eshanth and age is 18

# %%
a=5
b=7
print(f"the sum of {a} and {b} is {a+b}")
print(f"the upper case of name is {name.upper()}")
# Out:
# the sum of 5 and 7 is 12
# the upper case of name is ESHANTH

# %%
## dictionary

d={
    "esh":1,
    "arjun":2
}
print(d.setdefault("esh",9))
for k,v in d.items():
    print(k,v)
# Out:
# 1
# esh 1
# arjun 2

# %%
d = {1:1,2:4,3:9,4:16,5:25,6:36,7:49,8:64,9:81,10:100}
print(d)
a = {i:i**2 for i in range(1,11)}
print(a)
sort = sorted(a.items())
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
d = {"Yash":17,"Varma":18,"Karthikeya":19}
print(d["Yash"])
print(d.get("omkar"))
print(d.keys())
print(d.values())
print(d.items())
print(d.pop("Yash"))
print(d.setdefault("omkar",17))
print(d)
d["Yash"] = 19
print(d)
d.popitem()
print(d)
# Out:
# 17
# None
# dict_keys(['Yash', 'Varma', 'Karthikeya'])
# dict_values([17, 18, 19])
# dict_items([('Yash', 17), ('Varma', 18), ('Karthikeya', 19)])
# 17
# 17
# {'Varma': 18, 'Karthikeya': 19, 'omkar': 17}
# {'Varma': 18, 'Karthikeya': 19, 'omkar': 17, 'Yash': 19}
# {'Varma': 18, 'Karthikeya': 19, 'omkar': 17}

# %%
college = {
    "CS":{"hod":"kjhf","students":99},
    "EC":{"hod":"jklgsk","students":49}
}
for branch in college.keys():
    print(college[branch]["hod"])
# Out:
# kjhf
# jklgsk

# %%
email = input().strip()

if email.count('@') == 1:
    ch = email.split('@')
    s1 = ch[0]
    s2 = ch[1]

    if s1.isalpha() and email.endswith(".com"):
        print("Valid email")
    else:
        print("Invalid email")
else:
    print("Invalid email")
# Out:
# Invalid email

# %%
str=" 45, 88 ,72,91, 60 "
arr=str.split(",")
ia = list(map(int, arr))
print(sum(ia))
print(sum(ia)//len(ia))
# Out:
# 356
# 71

# %%
str=input()
str=str.strip()
str=str.title()
if str.replace(" ","").isalpha()==False:
    print("Invalid name")
else:
    print(str)
# Out:
# Eshanth Arjun

# %%
print("google.com".endswith('.com'))
# Out:
# True

# %%
print("hel".startswith('h'))
print("hel".startswith('H'))
print("@hdkj".startswith('@'))
# Out:
# True
# False
# True

# %%
print('123'.isdigit())
print('123fdsf'.isdigit())
# Out:
# True
# False

# %%
print('heello'.isalpha())  ## true
print('heello22'.isalpha())  ## false
# Out:
# True
# False
